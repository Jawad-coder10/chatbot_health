# %% [markdown]
# # Intent classification with BERT
# This notebook trains a multilingual BERT classifier to recognize user intents from text.
#
# We will:
# 1. Load the CSV dataset.
# 2. Map text labels to numeric IDs.
# 3. Split the data into training, validation, and test sets.
# 4. Tokenize the text for a transformer model.
# 5. Load a pretrained model and fine-tune it.
# 6. Train using the Hugging Face Trainer API.
#
# Each code cell is explained with the theory behind what it does.

# %%
# %pip install -U "accelerate>=1.1.0" "transformers[torch]"
# Out:
# Requirement already satisfied: accelerate>=1.1.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (1.13.0)
# Requirement already satisfied: transformers[torch] in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (5.8.1)
# Requirement already satisfied: numpy>=1.17 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from accelerate>=1.1.0) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from accelerate>=1.1.0) (26.2)
# Requirement already satisfied: psutil in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from accelerate>=1.1.0) (7.2.2)
# Requirement already satisfied: pyyaml in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from accelerate>=1.1.0) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from accelerate>=1.1.0) (2.12.0+cpu)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from accelerate>=1.1.0) (1.15.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from accelerate>=1.1.0) (0.7.0)
# Requirement already satisfied: regex>=2025.10.22 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from transformers[torch]) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from transformers[torch]) (0.22.2)
# Requirement already satisfied: typer in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from transformers[torch]) (0.25.1)
# Requirement already satisfied: tqdm>=4.27 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from transformers[torch]) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=1.1.0) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=1.1.0) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=1.1.0) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=1.1.0) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=1.1.0) (4.15.0)
# Requirement already satisfied: anyio in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate>=1.1.0) (4.13.0)
# Requirement already satisfied: certifi in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate>=1.1.0) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate>=1.1.0) (1.0.9)
# Requirement already satisfied: idna in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate>=1.1.0) (3.13)
# Requirement already satisfied: h11>=0.16 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate>=1.1.0) (0.16.0)
# Requirement already satisfied: setuptools<82 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from torch>=2.0.0->accelerate>=1.1.0) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from torch>=2.0.0->accelerate>=1.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from torch>=2.0.0->accelerate>=1.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from torch>=2.0.0->accelerate>=1.1.0) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=1.1.0) (1.3.0)
# Requirement already satisfied: colorama in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from tqdm>=4.27->transformers[torch]) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from typer->transformers[torch]) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from typer->transformers[torch]) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from typer->transformers[torch]) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from typer->transformers[torch]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from rich>=13.8.0->typer->transformers[torch]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from rich>=13.8.0->typer->transformers[torch]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers[torch]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages (from jinja2->torch>=2.0.0->accelerate>=1.1.0) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys, transformers, accelerate
from transformers.utils import is_accelerate_available

print("python:", sys.executable)
print("transformers:", transformers.__version__)
print("accelerate:", accelerate.__version__)
print("accelerate ok:", is_accelerate_available())
print("accelerate file:", accelerate.__file__)
# Out:
# python: c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Scripts\python.exe
# transformers: 5.8.1
# accelerate: 1.13.0
# accelerate ok: True
# accelerate file: c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Lib\site-packages\accelerate\__init__.py

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset
import torch

# %% [markdown]
# ## Imports and libraries
# - `pandas` handles tabular data from CSV files.
# - `sklearn.model_selection.train_test_split` splits data into train, validation, and test sets.
# - `transformers` provides pretrained models and tokenizers from Hugging Face.
# - `datasets.Dataset` converts pandas data into a format suitable for transformer training.
# - `torch` is the underlying deep learning framework used by the model.

# %%
df=pd.read_csv(r'C:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\datasets\intent\dataset_f.csv')

# %% [markdown]
# ## Dataset loading from CSV
# Load the CSV file containing the intent dataset into a pandas DataFrame.
# Each row is one example with text and an intent label.
#
# This is the raw data source for training and evaluation.

# %%
labels = df["intent"].unique().tolist()
label2id = {l: i for i, l in enumerate(labels)}
id2label = {i: l for l, i in label2id.items()}
df["label"] = df["intent"].map(label2id)

# %% [markdown]
# ## Label encoding
# Machine learning models require numeric labels, not text strings.
# This cell builds two dictionaries:
# - `label2id`: map string labels to numbers
# - `id2label`: map numbers back to strings
#
# Then it applies the numeric label to the dataset.

# %%
train, temp = train_test_split(df, test_size=0.3, random_state=42)
val, test = train_test_split(temp, test_size=0.5, random_state=42)

# %% [markdown]
# ## Train/validation/test split
# Split the dataset into three parts:
# - training set: used to teach the model
# - validation set: used to tune hyperparameters and check for overfitting during training
# - test set: used once at the end to evaluate final performance
#
# Using `random_state` ensures the split is reproducible.

# %%
print(f"Train size: {len(train)}, Validation size: {len(val)}, Test size: {len(test)}")
# Out:
# Train size: 734, Validation size: 157, Test size: 158

# %% [markdown]
# ## Data size check
# Print the size of each subset to confirm the split proportion.
# This helps verify there is enough data for training and evaluation.

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-multilingual-cased")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %% [markdown]
# ## Tokenizer loading
# Load a pretrained tokenizer for multilingual BERT.
# A tokenizer converts raw text into token IDs and attention masks, which are the numerical inputs the model understands.
# This tokenizer supports many languages, so it can handle both Roman-script text and Arabic text in the same dataset.
#
# Note: the tokenizer does not train on your data; it only converts your text into the format required by the model.

# %%
def tokenize(batch):
    return tokenizer(batch["text"], padding=True, truncation=True, max_length=128)

train_dataset = Dataset.from_pandas(train[["text", "label"]])
val_dataset = Dataset.from_pandas(val[["text", "label"]])
test_dataset = Dataset.from_pandas(test[["text", "label"]])

train_dataset = train_dataset.map(tokenize, batched=True)
val_dataset = val_dataset.map(tokenize, batched=True)
test_dataset = test_dataset.map(tokenize, batched=True)
# Out:
# Map:   0%|          | 0/734 [00:00<?, ? examples/s]
# Map:   0%|          | 0/157 [00:00<?, ? examples/s]
# Map:   0%|          | 0/158 [00:00<?, ? examples/s]

# %% [markdown]
# ## Tokenization and dataset conversion
# This cell:
# 1. Defines a `tokenize` function that converts raw text to token IDs and attention masks.
# 2. Creates Hugging Face `Dataset` objects from pandas data.
# 3. Applies the tokenizer to each split with batching.
#
# The resulting datasets are ready to feed into the transformer model.

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    "bert-base-multilingual-cased",
    num_labels=len(label2id),
    id2label=id2label,
    label2id=label2id
)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-multilingual-cased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %% [markdown]
# ## Load pretrained model for classification
# Load a multilingual BERT model with a sequence classification head.
# The `num_labels` argument tells the model how many intent classes to predict.
# Providing `id2label` and `label2id` ensures output labels are human-readable.

# %%
import accelerate
print(accelerate.__version__)
# Out:
# 1.13.0

# %% [markdown]
# ## Accelerator version check
# The `accelerate` library helps manage hardware and distributed training.
# Here we simply print the version to confirm it is installed and available.

# %%
from transformers.utils import is_accelerate_available

# Clear cached backend availability from older runs in this notebook session.
is_accelerate_available.cache_clear()

training_args = TrainingArguments(
    output_dir="./results",
    num_train_epochs=5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    dataloader_pin_memory=False,
    eval_strategy="epoch",
    save_strategy="no",
    load_best_model_at_end=False,
    logging_dir="./logs"
)
# Out:
# [transformers] `logging_dir` is deprecated and will be removed in v5.2. Please set `TENSORBOARD_LOGGING_DIR` instead.

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Inconnu\OneDrive\Bureau\Master_IT\Academic_project\chatbot_health\backend\venv\Scripts\python.exe

# %% [markdown]
# ## Training configuration
# Define the training behavior with Hugging Face `TrainingArguments`.
# - `output_dir`: folder for saved checkpoints
# - `num_train_epochs`: how many passes over the training data
# - `per_device_train_batch_size`: batch size per GPU/CPU device
# - `eval_strategy` and `save_strategy`: how often to evaluate and save
# - `load_best_model_at_end`: keep the best validation model

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset
)

# %% [markdown]
# ## Trainer setup
# Create the `Trainer` object which orchestrates training, evaluation, and optimization.
# It takes the model, training arguments, and datasets, and handles the training loop internally.

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='230' max='230' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [230/230 17:12, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.430279</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.774399</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.456518</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.352498</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.327566</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=230, training_loss=0.7775256613026494, metrics={'train_runtime': 1046.4293, 'train_samples_per_second': 3.507, 'train_steps_per_second': 0.22, 'total_flos': 54695638195500.0, 'train_loss': 0.7775256613026494, 'epoch': 5.0})

# %% [markdown]
# ## Start fine-tuning
# Run the training process.
# The `Trainer` will iterate over the training data, compute loss, update model weights, and evaluate on the validation set at each epoch.

# %% [markdown]
# ## Save the trained model
# Save the fine-tuned model and tokenizer to disk so they can be reused later without retraining.
# The saved folder can be loaded again with `AutoModelForSequenceClassification.from_pretrained` and `AutoTokenizer.from_pretrained`.

# %%
model.save_pretrained("../models/intent_model/")
tokenizer.save_pretrained("../models/intent_model/tokenizer/")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ('../models/intent_model/tokenizer/tokenizer_config.json',
#  '../models/intent_model/tokenizer/tokenizer.json')

# %% [markdown]
# ## Evaluate on the test set
# Use the trained model to make predictions on the unseen test data.
# This step measures how well the model generalizes to new examples.

# %%
predictions = trainer.predict(test_dataset)
print(predictions.metrics)
# Out:
# {'test_loss': 0.5140143632888794, 'test_runtime': 11.2305, 'test_samples_per_second': 14.069, 'test_steps_per_second': 0.89}

# %% [markdown]
# ## Generate classification metrics
# Convert raw model scores into predicted labels and compare them to the true labels.
# Print a classification report showing precision, recall, and F1-score for each intent class.

# %%
import numpy as np
from sklearn.metrics import classification_report

preds = np.argmax(predictions.predictions, axis=1)
labels = predictions.label_ids

print(classification_report(labels, preds, target_names=list(label2id.keys())))
# Out:
#                         precision    recall  f1-score   support
#
#        demande_urgence       0.95      0.79      0.86        24
# remboursement_mutuelle       0.67      0.74      0.70        19
#   description_symptome       0.92      0.88      0.90        25
#      demande_posologie       0.88      0.92      0.90        25
#   demande_consultation       0.91      0.84      0.88        25
#     demande_medicament       0.84      0.91      0.88        23
#           demande_prix       0.68      0.76      0.72        17
#
#               accuracy                           0.84       158
#              macro avg       0.84      0.84      0.83       158
#           weighted avg       0.85      0.84      0.84       158

# %% [markdown]
# ## Real-world inference examples
# Load the fine-tuned model into a text classification pipeline and run it on example sentences.
# This demonstrates how the trained intent classifier can be used in a real application.

# %%
from transformers import pipeline

classifier = pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer
)

phrases = [
    "ki7ar9ni dahri m coinci 3liya"  ,
    "drabt yedi bel mouss"  
    

]

for phrase in phrases:
    result = classifier(phrase)
    print(f"{phrase} → {result[0]['label']} ({result[0]['score']:.2f})")
# Out:
# ki7ar9ni dahri m coinci 3liya → description_symptome (0.96)
# drabt yedi bel mouss → description_symptome (0.56)

# %%
import importlib
import accelerate
import transformers
from transformers.utils import is_accelerate_available

print('accelerate version:', accelerate.__version__)
print('before cache clear:', is_accelerate_available())

# Transformers caches backend checks; clear it to avoid stale state in long notebook sessions.
is_accelerate_available.cache_clear()
print('after cache clear:', is_accelerate_available())

# Also test from training_args module path used by TrainingArguments.
training_args_mod = importlib.import_module('transformers.training_args')
print('training_args sees accelerate:', training_args_mod.is_accelerate_available())
# Out:
# accelerate version: 1.13.0
# before cache clear: True
# after cache clear: True
# training_args sees accelerate: True
