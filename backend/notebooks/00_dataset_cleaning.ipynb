# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\hp\chatbot_health\data_sets\intent\arabe_darija.csv")
df2=pd.read_csv(r"C:\Users\hp\chatbot_health\data_sets\intent\arabizi_intent.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df1 = pd.read_csv(r"C:\Users\hp\chatbot_health\data_sets\intent\arabe_darija.csv")
#       2 df2=pd.read_csv(r"C:\Users\hp\chatbot_health\data_sets\intent\arabizi_intent.csv")
#       3
#       4
#
# ...

# %%
df_final = pd.concat([df1, df2]).sample(frac=1).reset_index(drop=True)
df_final.to_csv("intent_final.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_final = pd.concat([df1, df2]).sample(frac=1).reset_index(drop=True)
#       2 df_final.to_csv("intent_final.csv", index=False)
#       3
#
# NameError: name 'df1' is not defined

# %%
df_final.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_final.head()
#       2
#
# NameError: name 'df_final' is not defined

# %%
print(df_final.shape)
print(df_final["intent"].value_counts())
print(df_final.isnull().sum())
# Out:
# (1049, 3)
# intent
# demande_urgence           150
# remboursement_mutuelle    150
# description_symptome      150
# demande_posologie         150
# demande_consultation      150
# demande_medicament        150
# demande_prix              149
# Name: count, dtype: int64
# text        0
# intent      0
# language    0
# dtype: int64

# %%
df_1=pd.read_csv(r"C:\Users\hp\chatbot_health\backend\datasets\intent\aef_intet.csv")
print(df_1["intent"].value_counts())
# Out:
# intent
# demande_medicament        210
# demande_consultation      168
# demande_urgence           168
# demande_prix              168
# demande_posologie         168
# remboursement_mutuelle    168
# description_symptome      168
# pharmacie_garde            84
# intent                      2
# Name: count, dtype: int64

# %%
df11 = df_1[df_1['intent'] != 'pharmacie_garde']
df11.to_csv("intent_final2.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df11 = df_1[df_1['intent'] != 'pharmacie_garde']
#       2 df11.to_csv("intent_final2.csv", index=False)
#
# NameError: name 'df_1' is not defined

# %%
df11["intent"].value_counts()
# Out:
# intent
# demande_medicament        210
# demande_consultation      168
# demande_urgence           168
# demande_prix              168
# demande_posologie         168
# remboursement_mutuelle    168
# description_symptome      168
# intent                      2
# Name: count, dtype: int64

# %%
df11.head()
# Out:
#                                         phrase                intent language
# 0  I need an appointment with the doctor today  demande_consultation  english
# 1               Can you book a dentist for me?  demande_consultation  english
# 2      Pediatrician availability for tomorrow?  demande_consultation  english
# 3              I'd like to see a cardiologist.  demande_consultation  english
# 4       How to schedule a dermatologist visit?  demande_consultation  english

# %%
df_shuffled = df11.sample(frac=1, random_state=42)
df_shuffled = df_shuffled.reset_index(drop=True)
df_shuffled.head()
# Out:
#                        phrase                intent  language
# 0               طبيب المفاصل.  demande_consultation     arabe
# 1         Voir le chirurgien.  demande_consultation  francais
# 2  Heart attack, send medics!       demande_urgence   english
# 3               tbib d nboula  demande_consultation   arabizi
# 4        القلب كيضرب بالزربة.  description_symptome     arabe

# %%
df_shuffled.to_csv("intent_final2.csv", index=False)

# %%
intent_rows = df11[df11['label'] == 'intent']
print(f"Nombre de lignes 'intent' dans train : {len(intent_rows)}")
print(intent_rows.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 intent_rows = df11[df11['label'] == 'intent']
#       2 print(f"Nombre de lignes 'intent' dans train : {len(intent_rows)}")
#       3 print(intent_rows.head())
#
# NameError: name 'df11' is not defined

# %%
df_clean=pd.read_csv(r"C:\Users\hp\chatbot_health\backend\datasets\intent\intent_final2.csv")
print(df_clean["intent"].value_counts())
# Out:
# intent
# demande_medicament        210
# demande_consultation      168
# demande_urgence           168
# description_symptome      168
# demande_posologie         168
# remboursement_mutuelle    168
# demande_prix              168
# intent                      2
# Name: count, dtype: int64

# %%
# Drop les 2 lignes "intent" dans df_clean
df_clean = df_clean[df_clean['intent'] != 'intent'].copy()

# Vérifier
print(df_clean['intent'].value_counts())
# Out:
# intent
# demande_medicament        210
# demande_consultation      168
# demande_urgence           168
# description_symptome      168
# demande_posologie         168
# remboursement_mutuelle    168
# demande_prix              168
# Name: count, dtype: int64

# %%
df_clean['intent'].value_counts()
# Out:
# intent
# demande_medicament        210
# demande_consultation      168
# demande_urgence           168
# description_symptome      168
# demande_posologie         168
# remboursement_mutuelle    168
# demande_prix              168
# Name: count, dtype: int64

# %%
df_clean.to_csv("intent_final22.csv", index=False)
